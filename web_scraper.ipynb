# %%
from time import strftime,localtime
import pandas as pd
from os.path import exists

# %%
class Team_standings:
    
    def __init__(self):
        self.REG = 0
        self.PRE = 1
        self.labels=("regular_season", "pre_season")
        team_abbrvs = pd.read_csv("team_names.csv",usecols=["prefix_1"])
        self.team_names = "|".join(list(team_abbrvs["prefix_1"].str.upper()))
        del team_abbrvs
    
    
    def build_table(self,url):
        dfs = pd.read_html(url)
        stats = dfs[1] 
        teams = dfs[0]
        teams = teams.rename(columns={0:"Team"})

        return teams.join(stats)
    
    def gen_key(self, year, season_type):
        return year+"_"+season_type

    def build_url(self, root,year_n, tail,preseason = False):
        if(not preseason):
            return root +  "/" + year_n + tail
        else:
            return root + "/" + year_n + tail
        
    def update_team_standings(self):
        self.REG = 0
        self.PRE = 1
        this_year = strftime("%Y",localtime())

        
        root = "https://www.espn.com/nba/standings/_"
        tail = "/group/league"
        
        filename = self.gen_key(this_year, self.labels[self.REG]) + ".csv"
        filepath = "./team_standings/reg_season/" +filename

        this_year_reg_season = root + tail
        table = self.build_table(this_year_reg_season)
        
        self.preprocess(table,False)
        table.to_csv(filepath, index = False)
        
        filename = self.gen_key(this_year, self.labels[self.PRE]) + ".csv"
        filepath = "./team_standings/pre_season/" +filename
        
        this_year_pre_season = root + "/seasontype/pre" + tail
        table = self.build_table(this_year_pre_season)
        
        self.preprocess(table,False)
        table.to_csv(filepath, index = False)

        return
    
    def preprocess(self, df, complete_league = True):
        
        if(complete_league):
            df["Team"] = df["Team"].str.extract(r'(^.+--)(.+)',expand = True)[1]
        
        processed = df["Team"].str.extract(fr'({self.team_names})(.+)',expand=True)
        
        df.insert(0,"ID",processed[0])
        df["Team"] = processed[1]
        
        return df
        
        
    def save_standings(self,filepath,year,preseason = False):
        if(exists(filepath)):
            return
        
        root = "https://www.espn.com/nba/standings/_"
        tail = "/group/league"
        
        
        if(preseason):
            preseason_root = root + "/seasontype/pre/season"
            season = self.build_url(preseason_root, year, tail)
            table = self.build_table(season)
            self.preprocess(table,False)
        else:
            reg_season_root = root + "/season"
            season = self.build_url(reg_season_root, year, tail)
            table = self.build_table(season)
            self.preprocess(table)
            
        table.to_csv(filepath, index = False)
        
        return

    
    def get_team_standings(self, last_n_years):
        self.REG = 0
        self.PRE = 1
        this_year = strftime("%Y",localtime())

        year = int(this_year)

        for y in range(year,year-last_n_years,-1):
            filename = self.gen_key(str(y-1),self.labels[self.REG]) + ".csv"
            filepath = "./team_standings/reg_season/" + filename
            
            self.save_standings(filepath,year = str(y-1))
            
            filename = self.gen_key(str(y-1),self.labels[self.PRE]) + ".csv"
            filepath = "./team_standings/pre_season/" + filename
            
            self.save_standings(filepath,year=str(y-1),preseason=True)

                
        return

# %%
standings_scraper = Team_standings()

# %%
standings_scraper.get_team_standings(5)

# %%
standings_scraper.update_team_standings()

# %%
df = pd.read_csv("team_standings/reg_season/2016_regular_season.csv")

# %%
df
# Out:
#       ID                    Team   W   L    PCT  GB   HOME   AWAY   DIV  \
# 0     GS   Golden State Warriors  73   9  0.890   -   39-2   34-7  15-1
# 1     SA       San Antonio Spurs  67  15  0.817   6   40-1  27-14  14-2
# 2    CLE     Cleveland Cavaliers  57  25  0.695  16   33-8  24-17   8-8
# 3    TOR         Toronto Raptors  56  26  0.683  17   32-9  24-17  14-2
# 4    OKC   Oklahoma City Thunder  55  27  0.671  18   32-9  23-18  13-3
# 5    LAC             LA Clippers  53  29  0.646  20  29-12  24-17   9-7
# 6    MIA              Miami Heat  48  34  0.585  25  28-13  20-21  10-6
# 7    ATL           Atlanta Hawks  48  34  0.585  25  27-14  21-20   8-8
# 8    BOS          Boston Celtics  48  34  0.585  25  28-13  20-21  10-6
# 9    CHA       Charlotte Hornets  48  34  0.585  25  30-11  18-23   8-8
# 10   IND          Indiana Pacers  45  37  0.549  28  26-15  19-22   8-8
# 11   POR  Portland Trail Blazers  44  38  0.537  29  28-13  16-25  11-5
# 12   DET         Detroit Pistons  44  38  0.537  29  26-15  18-23  10-6
# 13   DAL        Dallas Mavericks  42  40  0.512  31  23-18  19-22   7-9
# 14   MEM       Memphis Grizzlies  42  40  0.512  31  26-15  16-25   7-9
# 15   CHI           Chicago Bulls  42  40  0.512  31  26-15  16-25  10-6
# 16   HOU         Houston Rockets  41  41  0.500  32  23-18  18-23   8-8
# 17   WSH      Washington Wizards  41  41  0.500  32  22-19  19-22  10-6
# 18  UTAH               Utah Jazz  40  42  0.488  33  24-17  16-25   8-8
# 19   ORL           Orlando Magic  35  47  0.427  38  23-18  12-29  4-12
# 20   SAC        Sacramento Kings  33  49  0.402  40  18-23  15-26   8-8
# 21   DEN          Denver Nuggets  33  49  0.402  40  18-23  15-26  4-12
# 22   MIL         Milwaukee Bucks  33  49  0.402  40  23-18  10-31  4-12
# 23    NY         New York Knicks  32  50  0.390  41  18-23  14-27   8-8
# 24    NO    New Orleans Pelicans  30  52  0.366  43  21-20   9-32  4-12
# 25   MIN  Minnesota Timberwolves  29  53  0.354  44  14-27  15-26  4-12
# 26   PHX            Phoenix Suns  23  59  0.280  50  14-27   9-32  6-10
# 27   BKN           Brooklyn Nets  21  61  0.256  52  14-27   7-34  6-10
# 28   LAL      Los Angeles Lakers  17  65  0.207  56  12-29   5-36  2-14
# 29   PHI      Philadelphia 76ers  10  72  0.122  63   7-34   3-38  2-14
#
#      CONF    PPG  OPP PPG  DIFF STRK   L10
# 0    46-6  114.9    104.1  10.8   W4   8-2
# 1    43-9  103.5     92.9  10.6   W2   6-4
# 2   35-17  104.3     98.3   6.0   L1   6-4
# 3   39-13  102.7     98.2   4.5   W4   7-3
# 4   37-15  110.2    102.9   7.3   L1   5-5
# 5   31-21  104.5    100.2   4.3   L1   8-2
# 6   31-21  100.0     98.4   1.6   L1   6-4
# 7   29-23  102.8     99.2   3.6   L2   6-4
# 8   31-21  105.7    102.5   3.2   W1   6-4
# 9   33-19  103.4    100.7   2.7   W2   7-3
# 10  30-22  102.2    100.5   1.7   W3   7-3
# 11  29-23  105.1    104.3   0.8   W1   7-3
# 12  29-23  102.0    101.4   0.6   W1   6-4
# 13  27-25  102.3    102.6  -0.3   L1   7-3
# 14  25-27   99.1    101.3  -2.2   L4   1-9
# 15  25-27  101.6    103.1  -1.5   W3   6-4
# 16  28-24  106.5    106.4   0.1   W3   6-4
# 17  30-22  104.1    104.6  -0.5   W3   6-4
# 18  24-28   97.7     95.9   1.8   L2   5-5
# 19  21-31  102.1    103.7  -1.6   L1   6-4
# 20  19-33  106.6    109.1  -2.5   L1   5-5
# 21  18-34  101.9    105.0  -3.1   L2   3-7
# 22  21-31   99.0    103.2  -4.2   L2   3-7
# 23  21-31   98.4    101.1  -2.7   L2   3-7
# 24  20-32  102.7    106.5  -3.8   L3   4-6
# 25  18-34  102.4    106.0  -3.6   W1   5-5
# 26  17-35  100.9    107.5  -6.6   W1   3-7
# 27  12-40   98.6    106.0  -7.4  L10  0-10
# 28   8-44   97.3    106.9  -9.6   W1   2-8
# 29   3-49   97.4    107.6 -10.2   L4   1-9
