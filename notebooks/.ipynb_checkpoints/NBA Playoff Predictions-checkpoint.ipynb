# %% [markdown]
# The NBA playoffs are coming soon and the brckets are almost completely set. This notebook aims to make predictions for these playoffs.
#
# This project delivers value by:
# - revealing indicators of success that tend to appear in the NBA
# - providing data to identify strategies that need to be adjusted

# %%
inner_select = "(SELECT Teams.Name AS Team, Box_scores.* FROM Box_scores INNER JOIN Teams ON Box_scores.Team_ID = Teams.ID) B "
outer_select = "SELECT Players.Name AS Player, B.* FROM " + inner_select + "INNER JOIN Players ON Players.ID = B.Player_ID"

join =  "Box_scores INNER JOIN Players on Box_scores.Player_ID = Players.ID "

command = outer_select + " ORDER BY Game_day desc"

box_scores = pd.read_sql(command,engine,parse_dates=["Game_day"])

# %%
drop_columns = ['Player_ID','Team_ID']

box_scores = box_scores.drop(columns = drop_columns)

# %%
import sqlalchemy
from os import environ

import numpy as np
import pandas as pd

# %%
engine = sqlalchemy.create_engine("mariadb+mariadbconnector://"+environ.get("USER")+\
                                  ":"+environ.get("PSWD")+"@127.0.0.1:3306/nba")

# %%
command = "SELECT Teams.Name AS Team, Team_standings.* FROM Team_standings INNER JOIN Teams ON Team_standings.Team_ID = Teams.ID "

team_averages = pd.read_sql(command,engine)

# %%
drop_columns = ['TEAM_ID']
team_averages = team_averages.drop(columns=drop_columns)

# %%
team_averages['Year'] = team_averages['SEASON_ID'].str.slice(3)

# %%
team_averages['Playoffs'] = True

# %%
r = team_averages.loc[team_averages['Team']=='MIA']

counts = team_averages.value_counts(['Team','Year'],sort=False)

# %%
j = 0
for i in counts.index:
    if(j%10):
        print(i[0],i[1],counts[i])
    j+=1
# Out:
# ATL 01 1
# ATL 02 1
# ATL 03 1
# ATL 04 1
# ATL 05 1
# ATL 06 1
# ATL 07 2
# ATL 08 2
# ATL 09 2
# ATL 11 2
# ATL 12 2
# ATL 13 2
# ATL 14 2
# ATL 15 2
# ATL 16 2
# ATL 17 1
# ATL 18 1
# ATL 19 1
# ATL 21 1
# ATL 95 1
# ATL 96 2
# ATL 97 2
# ATL 98 2
# ATL 99 1
# BKN 00 1
# BKN 01 2
# BKN 02 2
# BKN 04 2
# BKN 05 2
# BKN 06 2
# BKN 07 1
# BKN 08 1
# BKN 09 1
# BKN 10 1
# BKN 11 1
# BKN 12 2
# BKN 14 2
# BKN 15 1
# BKN 16 1
# BKN 17 1
# BKN 18 2
# BKN 19 2
# BKN 20 2
# BKN 21 1
# BKN 95 1
# BKN 97 2
# BKN 98 1
# BKN 99 1
# BOS 00 1
# BOS 01 2
# BOS 02 2
# BOS 03 2
# BOS 04 2
# BOS 05 1
# BOS 07 2
# BOS 08 2
# BOS 09 2
# BOS 10 2
# BOS 11 2
# BOS 12 2
# BOS 13 1
# BOS 14 2
# BOS 15 2
# BOS 17 2
# BOS 18 2
# BOS 19 2
# BOS 20 2
# BOS 21 1
# BOS 95 1
# BOS 96 1
# BOS 97 1
# BOS 98 1
# CHA 00 2
# CHA 01 2
# CHA 04 1
# CHA 05 1
# CHA 06 1
# CHA 07 1
# CHA 08 1
# CHA 09 2
# CHA 10 1
# CHA 12 1
# CHA 13 2
# CHA 14 1
# CHA 15 2
# CHA 16 1
# CHA 17 1
# CHA 18 1
# CHA 19 1
# CHA 20 1
# ...

# %%
# Out:
# Int64Index([ 81,  82,  83,  84,  85,  86,  87,  88,  89,  90,  91,  92,  93,
#              94,  95,  96,  97,  98,  99, 100, 101, 102, 103, 104, 105],
#            dtype='int64')

# %%
team_averages['Appearances'] = team_averages.groupby(["Team",'Year'],as_index=False).count()['Y']

# %%
team_averages['Playoffs'] = team_averages['Playoffs'].where(team_averages['Appearances']>1,False).sum()

# %%
team_averages.iloc[t.loc[t['Team']== 'CHA'].index]
# Out:
#     Team SEASON_ID  GP   W   L    WINP    MINS    PTS    FGM   FGA  ...   TOV  \
# 81   BOS     00420   5   1   4   0.200  48.000  112.2   38.4  88.2  ...  13.0
# 82   BOS     00220  72  36  36   0.500  48.300  112.6   41.5  88.9  ...  14.1
# 83   BOS     00295  13  56  31  25.000   0.554   48.7  108.4  39.6  ...  23.5
# 84   BOS     00221  60  34  26   0.567  48.700  108.9   39.7  87.5  ...  14.1
# 85   CLE     00414  20  14   6   0.700  48.800   99.0   34.7  82.7  ...  13.0
# 86   CLE     00214  82  53  29   0.646  48.200  103.1   37.7  82.2  ...  14.3
# 87   CLE     00219  65  19  46   0.292  48.400  106.9   40.3  87.9  ...  16.5
# 88   CLE     00407  13   7   6   0.538  48.000   89.9   31.1  74.1  ...  13.8
# 89   CLE     00207  82  45  37   0.549  48.400   96.4   35.8  81.7  ...  14.0
# 90   CLE     00200  82  30  52   0.366  48.400   92.2   35.2  79.7  ...  16.5
# 91   CLE     00299  82  32  50   0.390  48.400   97.0   36.3  82.1  ...  17.4
# ...

# %%
for t in team_averages["Team"].unique():
#     print(t)
    r = team_averages.loc[team_averages['Team']==t]
    counts = r['Year'].value_counts()
    for i in counts.index:
        r.loc[r['Year']==i]['Playoffs'] = counts[i]==2
# for i in team_averages.loc[team_averages['Team']==t]['Year'].value_counts().index:
#     print(i)
r
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Team SEASON_ID  GP   W   L    WINP  MINS    PTS    FGM   FGA  ...   REB  \
# 1169  CHA     00214  82  33  49   0.402  48.5   94.2   35.5  84.5  ...  44.1
# 1170  CHA     00219  65  23  42   0.354  48.5  102.9   37.3  85.9  ...  42.8
# 1171  CHA     00207  82  32  50   0.390  48.5   97.1   36.1  79.9  ...  40.6
# 1172  CHA     00400  10   6   4   0.600  48.0   95.7   33.9  78.1  ...  43.1
# 1173  CHA     00200  82  46  36   0.561  48.5   91.9   34.1  79.3  ...  44.4
# 1174  CHA     00499   4   1   3   0.250  49.3   91.3   32.3  75.0  ...  44.0
# 1175  CHA     00299  82  49  33   0.598  48.2   98.4   35.8  79.7  ...  42.9
# ...

# %%
playoff_teams = team_averages.loc[team_averages['SEASON_ID'].str.contains('^004',regex = True)].index
regular_seasons = team_averages.loc[team_averages['SEASON_ID'].str.contains('^002',regex = True)].index

# %%
pd.merge(playoff_teams, regular_seasons,how='left',)

# %%
team_averages.loc[playoff_teams,'Playoffs'] = True
team_averages.loc[regular_seasons,'Playoffs'] = False

# %%
team_averages
# Out:
#      Team SEASON_ID  GP   W   L    WINP  MINS    PTS    FGM   FGA  ...  DREB  \
# 0     ATL     00414  16   8   8   0.500  48.6   98.0   36.9  85.6  ...  33.9
# 1     ATL     00214  82  60  22   0.732  48.1  102.5   38.1  81.7  ...  31.8
# 2     ATL     00219  67  20  47   0.299  48.6  111.8   40.6  90.6  ...  33.4
# 3     ATL     00407   7   3   4   0.429  48.0   87.1   29.3  71.3  ...  26.7
# 4     ATL     00207  82  37  45   0.451  48.4   98.2   36.3  79.9  ...  29.9
# ...   ...       ...  ..  ..  ..     ...   ...    ...    ...   ...  ...   ...
# 1197  CHA     00212  82  21  61   0.256  48.3   93.4   34.4  81.1  ...  29.1
# 1198  CHA     00211  66   7  59   0.106  48.2   87.0   33.2  80.2  ...  28.7
# 1199  CHA     00220  72  33  39   0.458  48.2  109.5   39.9  87.8  ...  33.2
# 1200  CHA     00295  16  56  28  28.000   0.5   48.4  113.3  42.1  ...  10.7
# 1201  CHA     00221  60  29  31   0.483  48.6  113.8   42.1  92.3  ...  34.1
#
# ...
