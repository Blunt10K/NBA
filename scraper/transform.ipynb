# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.getOrCreate()
# Out:
# 23/05/01 20:58:07 WARN Utils: Your hostname, rpi3 resolves to a loopback address: 127.0.1.1; using 10.123.198.155 instead (on interface wlan0)
# 23/05/01 20:58:07 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/home/blunt/.local/lib/python3.9/site-packages/pyspark/jars/spark-unsafe_2.12-3.2.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# ...

# %%
df = spark.read.parquet('outputs')
# Out:
# 23/05/01 20:59:28 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
df.printSchema()
# Out:
# root
#  |-- analyticsObject: struct (nullable = true)
#  |    |-- gameBroadcasters: string (nullable = true)
#  |    |-- gameID: string (nullable = true)
#  |    |-- gameMatchup: string (nullable = true)
#  |    |-- gameQuarter: string (nullable = true)
#  |    |-- gameState: string (nullable = true)
#  |    |-- season: long (nullable = true)
#  |    |-- seasonType: string (nullable = true)
#  |    |-- venue: string (nullable = true)
#  |-- boxscoreParams: struct (nullable = true)
#  |    |-- defaultRangeString: string (nullable = true)
#  |    |-- initialBoxscoreCacheKey: string (nullable = true)
#  |-- game: struct (nullable = true)
#  |    |-- arena: struct (nullable = true)
#  |    |    |-- arenaCity: string (nullable = true)
#  |    |    |-- arenaCountry: string (nullable = true)
#  |    |    |-- arenaId: long (nullable = true)
#  |    |    |-- arenaName: string (nullable = true)
#  |    |    |-- arenaPostalCode: string (nullable = true)
# ...

# %%
from pyspark.sql.functions import re

# %%
df.select('playByPlay.gameId','game.gameTimeUTC').show(truncate=False)
# Out:
# +----------+--------------------+
# |gameId    |gameTimeUTC         |
# +----------+--------------------+
# |0029700110|1997-11-15T03:00:00Z|
# |0021800928|2019-03-02T00:30:00Z|
# |0029800100|1999-02-18T03:00:00Z|
# |0021600711|2017-01-29T20:00:00Z|
# |0040300215|2004-05-14T23:00:00Z|
# |0029900004|1999-11-03T00:30:00Z|
# |0021100722|2012-03-25T22:00:00Z|
# |0041800233|2019-05-04T02:30:00Z|
# |0021401022|2015-03-20T23:30:00Z|
# |0042200105|2023-04-27T01:30:00Z|
# |0020500516|2006-01-14T01:00:00Z|
# |0022200835|2023-02-11T00:00:00Z|
# |0042200166|2023-04-29T00:00:00Z|
# |0021800853|2019-02-14T00:00:00Z|
# |0022200558|2023-01-03T03:00:00Z|
# |0029900985|2000-03-25T00:00:00Z|
# |0011600067|2016-10-16T00:00:00Z|
# |0021300864|2014-02-28T00:00:00Z|
# |0021600281|2016-12-02T03:30:00Z|
# |0020400159|2004-11-24T03:30:00Z|
# +----------+--------------------+
# only showing top 20 rows
