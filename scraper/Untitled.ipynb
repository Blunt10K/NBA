# %%
import pandas as pd

# %%
conda install pyarrow
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/blunt/miniforge3/envs/dev
#
#   added / updated specs:
#     - pyarrow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     arrow-cpp-12.0.0           |   h8af1aa0_0_cpu          28 KB  conda-forge
#     aws-c-auth-0.6.26          |       he1cc51f_6          96 KB  conda-forge
#     aws-c-cal-0.5.26           |       hfad698d_0          42 KB  conda-forge
#     aws-c-common-0.8.17        |       h31becfc_0         198 KB  conda-forge
#     aws-c-compression-0.2.16   |       h060b361_6          19 KB  conda-forge
#     aws-c-event-stream-0.2.20  |       hb501df5_6          54 KB  conda-forge
# ...

# %%
df = pd.read_parquet('outputs/')
